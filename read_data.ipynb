# %%
import pandas as pd

# %%
#https://gdc.cancer.gov/about-data/data-types-and-file-formats/generated-data-types-and-file-formats

#https://www.cell.com/cell/fulltext/S0092-8674(18)30229-0

# %%
directory= "C:\\Users\\Emil\\Documents\\Classes\\Fall_21\\Stat451_Machine_learning\\brca_tcga_pan_can_atlas_2018\\"
#filename = data_clinical_patient.tsv
filename = "data_rppa.txt"

# %%
filename_rppa_meta = 'meta_rppa.txt'
rppa_meta = pd.read_csv(directory+filename_rppa_meta)
rppa_meta

# %%
rppa = pd.read_csv(directory+filename, sep='\t',index_col=0, header=None)
#rppa_header = rppa.i
rppa = rppa.T
rppa
# Out:
# 0   Composite.Element.REF YWHAE|14-3-3_epsilon EIF4EBP1|4E-BP1  \
# 1         TCGA-EW-A2FR-01         -0.933957861     1.527210679
# 2         TCGA-EW-A2FS-01         -1.075067921    -0.542745813
# 3         TCGA-EW-A2FW-01         -0.736279806     0.006446741
# 4         TCGA-EW-A2FV-01         -1.021078507    -0.384183553
# 5         TCGA-EW-A1PC-01         -0.841824405     0.375902919
# ..                    ...                  ...             ...
# 872       TCGA-D8-A73W-01         -1.183984566     0.255406141
# 873       TCGA-BH-A6R9-01         -1.178910027     0.123704199
# 874       TCGA-EW-A6SD-01         -1.304363381     0.433853576
# 875       TCGA-EW-A6SB-01         -0.673711148     0.545889992
# 876       TCGA-EW-A6SC-01         -1.259361051    -0.809460479
#
# 0   EIF4EBP1|4E-BP1_pS65 EIF4EBP1|4E-BP1_pT37T46 TP53BP1|53BP1  \
# 1             0.18657915              2.22345188   1.852709836
# 2           -0.055206932             0.091812635   1.562517418
# 3           -0.158695125             0.144748846   2.135104454
# 4           -0.501669943             0.373442639    1.05958413
# 5           -0.137597029             0.581144537   1.618276487
# ..                   ...                     ...           ...
# 872          0.427703431             1.855740669   2.301119075
# 873          0.402208598             1.622056377   1.773957953
# 874          0.173326734             1.236153134   1.195379406
# 875          0.397194805              0.57919978   1.201689592
# 876          0.376075052             1.515305891   1.286458831
#
# 0   ACACA ACACB|ACC_pS79    ACACA|ACC1 AKT1 AKT2 AKT3|Akt  \
# 1           -0.199693828   1.574148113        1.185274625
# 2           -0.303943555   0.893212938        0.734894336
# 3            0.821032509   2.176466095         1.31092825
# 4            0.064331999   1.391836553        1.244011484
# 5            1.007566303   2.455908363        0.909910761
# ..                   ...           ...                ...
# 872         -0.389692779   1.239544462        1.056256731
# 873         -1.212968238   0.178357065        1.240367558
# 874          0.888374674   3.433152801        0.901439435
# 875         -1.252077769   1.149381766        0.769185292
# 876         -2.051287516  -1.187255567        0.129191154
#
# 0   AKT1 AKT2 AKT3|Akt_pS473  ...     MSH2|MSH2     MSH6|MSH6   DIABLO|Smac  \
# 1               -0.794798981  ...  -0.671516885   0.023978828   0.190056474
# 2               -1.237696527  ...  -0.858524285  -0.428178618   0.191627127
# 3               -1.728366433  ...  -0.675419273   0.342562463  -0.011046842
# 4               -0.891511977  ...  -0.798609762  -0.112163636   0.290364938
# 5               -1.288074251  ...  -0.056868681    0.71045111   -0.11677432
# ..                       ...  ...           ...           ...           ...
# 872              -1.71533931  ...  -1.931808599  -0.634281677   0.229934618
# 873             -0.182113239  ...  -1.920534957   -0.92525787  -0.534161477
# 874             -1.779894718  ...  -2.565216012    -1.2008848  -0.833074897
# 875             -1.927357703  ...  -0.784899087   0.451804801   0.441923386
# 876             -1.053997846  ...  -1.982933386  -1.492339478  -1.525777061
#
# 0   ADAR|ADAR1 CTNNA1|alpha-Catenin NKX2-1|TTF1 CASP3|Caspase-3  \
# 1          NaN                  NaN         NaN             NaN
# 2          NaN                  NaN         NaN             NaN
# 3          NaN                  NaN         NaN             NaN
# 4          NaN                  NaN         NaN             NaN
# 5          NaN                  NaN         NaN             NaN
# ..         ...                  ...         ...             ...
# 872        NaN                  NaN         NaN             NaN
# 873        NaN                  NaN         NaN             NaN
# 874        NaN                  NaN         NaN             NaN
# 875        NaN                  NaN         NaN             NaN
# 876        NaN                  NaN         NaN             NaN
#
# 0   CASP9|Caspase-9 PARP1|PARP1 COPS5|JAB1
# 1               NaN         NaN        NaN
# 2               NaN         NaN        NaN
# 3               NaN         NaN        NaN
# 4               NaN         NaN        NaN
# 5               NaN         NaN        NaN
# ..              ...         ...        ...
# 872             NaN         NaN        NaN
# 873             NaN         NaN        NaN
# 874             NaN         NaN        NaN
# 875             NaN         NaN        NaN
# 876             NaN         NaN        NaN
#
# [876 rows x 199 columns]

# %%
rppa['Composite.Element.REF']
# Out:
# 1      TCGA-EW-A2FR-01
# 2      TCGA-EW-A2FS-01
# 3      TCGA-EW-A2FW-01
# 4      TCGA-EW-A2FV-01
# 5      TCGA-EW-A1PC-01
#             ...
# 872    TCGA-D8-A73W-01
# 873    TCGA-BH-A6R9-01
# 874    TCGA-EW-A6SD-01
# 875    TCGA-EW-A6SB-01
# 876    TCGA-EW-A6SC-01
# Name: Composite.Element.REF, Length: 876, dtype: object

# %%
filename_ptdata = "data_clinical_patient.txt"
filename_ptsample = 'data_clinical_sample.txt'

# %%
pt_data_sample = pd.read_csv(directory+filename_ptsample, sep='\t')

# %%
data = pd.merge(pt_data_sample,rppa, left_on= 'Sample Identifier', right_on='Composite.Element.REF')

# %%
data
# Out:
#     #Patient Identifier Sample Identifier Oncotree Code  \
# 0          TCGA-3C-AALI   TCGA-3C-AALI-01           IDC
# 1          TCGA-3C-AALK   TCGA-3C-AALK-01           IDC
# 2          TCGA-4H-AAAK   TCGA-4H-AAAK-01           ILC
# 3          TCGA-5T-A9QA   TCGA-5T-A9QA-01        BRCNOS
# 4          TCGA-A1-A0SF   TCGA-A1-A0SF-01           IDC
# ..                  ...               ...           ...
# 871        TCGA-W8-A86G   TCGA-W8-A86G-01           ILC
# 872        TCGA-WT-AB41   TCGA-WT-AB41-01           IDC
# 873        TCGA-XX-A899   TCGA-XX-A899-01           ILC
# 874        TCGA-Z7-A8R5   TCGA-Z7-A8R5-01           ILC
# 875        TCGA-Z7-A8R6   TCGA-Z7-A8R6-01           ILC
#
#                    Cancer Type               Cancer Type Detailed  \
# 0    Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 1    Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 2    Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 3    Invasive Breast Carcinoma    Breast Invasive Carcinoma (NOS)
# 4    Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# ..                         ...                                ...
# 871  Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 872  Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 873  Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 874  Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 875  Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
#
#                          Tumor Type Neoplasm Histologic Grade  \
# 0     Infiltrating Ductal Carcinoma                       NaN
# 1     Infiltrating Ductal Carcinoma                       NaN
# 2    Infiltrating Lobular Carcinoma                       NaN
# 3                             Other                       NaN
# 4     Infiltrating Ductal Carcinoma                       NaN
# ..                              ...                       ...
# 871  Infiltrating Lobular Carcinoma                       NaN
# 872   Infiltrating Ductal Carcinoma                       NaN
# 873  Infiltrating Lobular Carcinoma                       NaN
# 874  Infiltrating Lobular Carcinoma                       NaN
# 875  Infiltrating Lobular Carcinoma                       NaN
#
#     Tissue Prospective Collection Indicator  \
# 0                                        No
# 1                                        No
# 2                                       Yes
# 3                                       Yes
# 4                                        No
# ..                                      ...
# 871                                     Yes
# 872                                      No
# 873                                      No
# 874                                      No
# 875                                      No
#
#     Tissue Retrospective Collection Indicator Tissue Source Site  ...  \
# 0                                         Yes                 3C  ...
# 1                                         Yes                 3C  ...
# 2                                          No                 4H  ...
# 3                                          No                 5T  ...
# 4                                         Yes                 A1  ...
# ..                                        ...                ...  ...
# 871                                        No                 W8  ...
# 872                                       Yes                 WT  ...
# 873                                       Yes                 XX  ...
# 874                                       Yes                 Z7  ...
# 875                                       Yes                 Z7  ...
#
#         MSH2|MSH2     MSH6|MSH6   DIABLO|Smac ADAR|ADAR1 CTNNA1|alpha-Catenin  \
# 0    -1.771334612  -0.499383881  -1.228354258        NaN                  NaN
# 1    -2.905149491  -0.314155662   -0.23618466        NaN                  NaN
# 2    -2.017104546  -0.158278361  -0.293197397        NaN                  NaN
# 3    -1.541832769   0.458540429  -0.574223609        NaN                  NaN
# 4    -0.766397831  -0.057478421  -0.197681571        NaN                  NaN
# ..            ...           ...           ...        ...                  ...
# 871  -0.378360151   1.286355917  -0.136075033        NaN                  NaN
# 872   -1.70113242  -0.435847596   0.682494567        NaN                  NaN
# 873   -1.40516723   0.277629496  -0.005706499        NaN                  NaN
# 874  -2.235970987  -0.757613449   0.710365191        NaN                  NaN
# 875  -1.735845421   0.677668485   0.915157951        NaN                  NaN
#
#     NKX2-1|TTF1 CASP3|Caspase-3 CASP9|Caspase-9 PARP1|PARP1 COPS5|JAB1
# 0           NaN             NaN             NaN         NaN        NaN
# 1           NaN             NaN             NaN         NaN        NaN
# 2           NaN             NaN             NaN         NaN        NaN
# 3           NaN             NaN             NaN         NaN        NaN
# 4           NaN             NaN             NaN         NaN        NaN
# ..          ...             ...             ...         ...        ...
# 871         NaN             NaN             NaN         NaN        NaN
# 872         NaN             NaN             NaN         NaN        NaN
# 873         NaN             NaN             NaN         NaN        NaN
# 874         NaN             NaN             NaN         NaN        NaN
# 875         NaN             NaN             NaN         NaN        NaN
#
# [876 rows x 216 columns]

# %%
pt_data = pd.read_csv(directory+filename_ptdata, sep='\t',header = 4)
print(pt_data.columns)
pt_data
# Out:
# Index(['PATIENT_ID', 'SUBTYPE', 'CANCER_TYPE_ACRONYM', 'OTHER_PATIENT_ID',
#        'AGE', 'SEX', 'AJCC_PATHOLOGIC_TUMOR_STAGE', 'AJCC_STAGING_EDITION',
#        'DAYS_LAST_FOLLOWUP', 'DAYS_TO_BIRTH',
#        'DAYS_TO_INITIAL_PATHOLOGIC_DIAGNOSIS', 'ETHNICITY',
#        'FORM_COMPLETION_DATE', 'HISTORY_NEOADJUVANT_TRTYN', 'ICD_10',
#        'ICD_O_3_HISTOLOGY', 'ICD_O_3_SITE', 'INFORMED_CONSENT_VERIFIED',
#        'NEW_TUMOR_EVENT_AFTER_INITIAL_TREATMENT', 'PATH_M_STAGE',
#        'PATH_N_STAGE', 'PATH_T_STAGE', 'PERSON_NEOPLASM_CANCER_STATUS',
#        'PRIMARY_LYMPH_NODE_PRESENTATION_ASSESSMENT', 'PRIOR_DX', 'RACE',
#        'RADIATION_THERAPY', 'WEIGHT', 'CENTER', 'IN_PANCANPATHWAYS_FREEZE',
#        'OS_STATUS', 'OS_MONTHS', 'DSS_STATUS', 'DSS_MONTHS', 'DFS_STATUS',
#        'DFS_MONTHS', 'PFS_STATUS', 'PFS_MONTHS'],
#       dtype='object')
#         PATIENT_ID    SUBTYPE CANCER_TYPE_ACRONYM  \
# 0     TCGA-3C-AAAU  BRCA_LumA                BRCA
# 1     TCGA-3C-AALI  BRCA_Her2                BRCA
# 2     TCGA-3C-AALJ  BRCA_LumB                BRCA
# 3     TCGA-3C-AALK  BRCA_LumA                BRCA
# 4     TCGA-4H-AAAK  BRCA_LumA                BRCA
# ...            ...        ...                 ...
# 1079  TCGA-WT-AB44  BRCA_LumA                BRCA
# 1080  TCGA-XX-A899  BRCA_LumA                BRCA
# 1081  TCGA-XX-A89A  BRCA_LumA                BRCA
# 1082  TCGA-Z7-A8R5  BRCA_LumA                BRCA
# 1083  TCGA-Z7-A8R6  BRCA_LumB                BRCA
#
#                           OTHER_PATIENT_ID  AGE     SEX  \
# 0     6E7D5EC6-A469-467C-B748-237353C23416   55  Female
# 1     55262FCB-1B01-4480-B322-36570430C917   50  Female
# 2     427D0648-3F77-4FFC-B52C-89855426D647   62  Female
# 3     C31900A4-5DCD-4022-97AC-638E86E889E4   52  Female
# 4     6623FC5E-00BE-4476-967A-CBD55F676EA6   50  Female
# ...                                    ...  ...     ...
# 1079  5CD79093-1571-4F71-8136-0D84CCABDCAC   77  Female
# 1080  F89588E9-CA73-4465-A7FB-7246EDB45E3A   46  Female
# 1081  CA20249F-B7EA-4FD9-9ECB-34F74755AE35   68  Female
# 1082  23F438BD-1DBB-4D46-972F-1E8E74DDBD37   61  Female
# 1083  B1D44C81-747D-471F-9093-AEB262A17975   46  Female
#
#      AJCC_PATHOLOGIC_TUMOR_STAGE AJCC_STAGING_EDITION  DAYS_LAST_FOLLOWUP  \
# 0                        STAGE X                  6TH              4047.0
# 1                      STAGE IIB                  6TH              4005.0
# 2                      STAGE IIB                  7TH              1474.0
# 3                       STAGE IA                  7TH              1448.0
# 4                     STAGE IIIA                  7TH               348.0
# ...                          ...                  ...                 ...
# 1079                    STAGE IA                  7TH               883.0
# 1080                  STAGE IIIA                  7TH               467.0
# 1081                   STAGE IIB                  7TH               488.0
# 1082                  STAGE IIIA                  6TH              3287.0
# 1083                     STAGE I                  6TH              3256.0
#
#       DAYS_TO_BIRTH  ...                    CENTER IN_PANCANPATHWAYS_FREEZE  \
# 0          -20211.0  ...       Columbia University                      Yes
# 1          -18538.0  ...       Columbia University                      Yes
# 2          -22848.0  ...       Columbia University                      Yes
# 3          -19074.0  ...       Columbia University                      Yes
# 4          -18371.0  ...         Proteogenex, Inc.                      Yes
# ...             ...  ...                       ...                      ...
# 1079            NaN  ...      University of Kansas                      Yes
# 1080       -17022.0  ...           Spectrum Health                      Yes
# 1081       -25000.0  ...           Spectrum Health                      Yes
# 1082       -22280.0  ...  John Wayne Cancer Center                      Yes
# 1083       -16955.0  ...  John Wayne Cancer Center                      Yes
#
#      OS_STATUS   OS_MONTHS                  DSS_STATUS  DSS_MONTHS  \
# 0     0:LIVING  133.050597  0:ALIVE OR DEAD TUMOR FREE  133.050597
# 1     0:LIVING  131.669790  0:ALIVE OR DEAD TUMOR FREE  131.669790
# 2     0:LIVING   48.459743  0:ALIVE OR DEAD TUMOR FREE   48.459743
# 3     0:LIVING   47.604958  0:ALIVE OR DEAD TUMOR FREE   47.604958
# 4     0:LIVING   11.440971  0:ALIVE OR DEAD TUMOR FREE   11.440971
# ...        ...         ...                         ...         ...
# 1079  0:LIVING   29.029819  0:ALIVE OR DEAD TUMOR FREE   29.029819
# 1080  0:LIVING   15.353256  0:ALIVE OR DEAD TUMOR FREE   15.353256
# 1081  0:LIVING   16.043660  0:ALIVE OR DEAD TUMOR FREE   16.043660
# 1082  0:LIVING  108.064569  0:ALIVE OR DEAD TUMOR FREE  108.064569
# 1083  0:LIVING  107.045402  0:ALIVE OR DEAD TUMOR FREE  107.045402
#
#                  DFS_STATUS  DFS_MONTHS     PFS_STATUS  PFS_MONTHS
# 0     1:Recurred/Progressed   59.440444  1:PROGRESSION   59.440444
# 1             0:DiseaseFree  131.669790     0:CENSORED  131.669790
# 2             0:DiseaseFree   48.459743     0:CENSORED   48.459743
# 3                       NaN         NaN     0:CENSORED   47.604958
# 4             0:DiseaseFree   11.440971     0:CENSORED   11.440971
# ...                     ...         ...            ...         ...
# 1079          0:DiseaseFree   29.029819     0:CENSORED   29.029819
# 1080          0:DiseaseFree   15.353256     0:CENSORED   15.353256
# 1081          0:DiseaseFree   16.043660     0:CENSORED   16.043660
# 1082                    NaN         NaN  1:PROGRESSION    5.950620
# 1083          0:DiseaseFree  107.045402     0:CENSORED  107.045402
#
# [1084 rows x 38 columns]

# %%
data = pd.merge(data,pt_data, left_on='#Patient Identifier', right_on= 'PATIENT_ID')

# %%
mutations_filename = "data_mutations_extended.txt"

# %%
mutations = pd.read_csv(directory+mutations_filename, sep='\t')
mutations
# Out:
#        Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 0            WDR11               0      .     GRCh37         10
# 1            GATA3               0      .     GRCh37         10
# 2           MALAT1               0      .     GRCh37         11
# 3            CD248               0      .     GRCh37         11
# 4            NPAS4               0      .     GRCh37         11
# ...            ...             ...    ...        ...        ...
# 130490       TRGV4               0      .     GRCh37          7
# 130491        PGA3               0      .     GRCh37         11
# 130492    KRTAP9-3               0      .     GRCh37         17
# 130493       ADH1A               0      .     GRCh37          4
# 130494  AL645922.1               0      .     GRCh37          6
#
#         Start_Position  End_Position Strand  \
# 0            122668955     122668955      +
# 1              8115874       8115875      +
# 2             65272906      65272908      +
# 3             66082467      66082467      +
# 4             66193652      66193652      +
# ...                ...           ...    ...
# 130490        38389382      38398537      +
# 130491        60971006      60989842      +
# 130492        39383290      39394642      +
# 130493       100203699     100235174      +
# 130494        31963535      31996273      +
#
#                                               Consequence  \
# 0                                     3_prime_UTR_variant
# 1                                      frameshift_variant
# 2                      non_coding_transcript_exon_variant
# 3                                        missense_variant
# 4                                     3_prime_UTR_variant
# ...                                                   ...
# 130490  splice_donor_variant,coding_sequence_variant,5...
# 130491  splice_acceptor_variant,splice_donor_variant,c...
# 130492        coding_sequence_variant,5_prime_UTR_variant
# 130493  splice_acceptor_variant,splice_donor_variant,c...
# 130494                                transcript_ablation
#
#        Variant_Classification  ...             ENSP ExAC_AF  \
# 0                       3'UTR  ...  ENSP00000263461       .
# 1             Frame_Shift_Ins  ...  ENSP00000368632       .
# 2                         RNA  ...                .       .
# 3           Missense_Mutation  ...  ENSP00000308117       .
# 4                       3'UTR  ...  ENSP00000311196       .
# ...                       ...  ...              ...     ...
# 130490            Splice_Site  ...  ENSP00000374868       .
# 130491            Splice_Site  ...  ENSP00000322192       .
# 130492                  5'UTR  ...  ENSP00000392189       .
# 130493            Splice_Site  ...  ENSP00000209668       .
# 130494            Splice_Site  ...  ENSP00000472615       .
#
#                                          CENTERS         CCDS    EXON  \
# 0       SOMATICSNIPER|RADIA|MUTECT|MUSE|VARSCANS   CCDS7619.1   29/29
# 1                  INDELOCATOR*|VARSCANI*|PINDEL  CCDS31143.1   6-Jun
# 2                               VARSCANI*|PINDEL            .   1-Jan
# 3                                MUTECT|VARSCANS   CCDS8134.1   1-Jan
# 4                     RADIA|MUTECT|MUSE|VARSCANS   CCDS8138.1   8-Aug
# ...                                          ...          ...     ...
# 130490                          VARSCANI*|PINDEL            .  1/2/02
# 130491                       INDELOCATOR*|PINDEL  CCDS31574.1  1/9/09
# 130492                       INDELOCATOR*|PINDEL  CCDS11385.1   1-Jan
# 130493                       INDELOCATOR*|PINDEL   CCDS3648.1  1/6/09
# 130494                       INDELOCATOR*|PINDEL            .  1/2/02
#
#        ExAC_AF_OTH SAS_MAF Exon_Number MINIMISED PUBMED
# 0                .       .       29/29         .      .
# 1                .       .       6-Jun         .      .
# 2                .       .       1-Jan         .      .
# 3                .     T:0       1-Jan         .      .
# 4                .       .       8-Aug         .      .
# ...            ...     ...         ...       ...    ...
# 130490           .       .      1/2/02         .      .
# 130491           .       .      1/9/09         .      .
# 130492           .       .       1-Jan         .      .
# 130493           .       .      1/6/09         .      .
# 130494           .       .      1/2/02         .      .
#
# [130495 rows x 113 columns]

# %%
mutations_mskcc_filename = "data_mutations_mskcc.txt"

# %%
mutations_mskcc = pd.read_csv(directory+mutations_mskcc_filename, sep='\t')
mutations_mskcc
# Out:
#        Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 0            WDR11               0      .     GRCh37         10
# 1            GATA3               0      .     GRCh37         10
# 2           MALAT1               0      .     GRCh37         11
# 3            CD248               0      .     GRCh37         11
# 4            NPAS4               0      .     GRCh37         11
# ...            ...             ...    ...        ...        ...
# 130490       STAG2               0      .     GRCh37          X
# 130491          GK               0      .     GRCh37          X
# 130492     CXorf67               0      .     GRCh37          X
# 130493        PHF8               0      .     GRCh37          X
# 130494       CABYR               0      .     GRCh37         18
#
#         Start_Position  End_Position Strand  \
# 0            122668955     122668955      +
# 1              8115874       8115875      +
# 2             65272906      65272908      +
# 3             66082467      66082467      +
# 4             66193652      66193652      +
# ...                ...           ...    ...
# 130490       123217344     123217344      +
# 130491        30671631      30671631      +
# 130492        51151398      51151398      +
# 130493        54014379      54014379      +
# 130494        21741479      21741479      +
#
#                                Consequence Variant_Classification  ...  \
# 0                      3_prime_UTR_variant                  3'UTR  ...
# 1                       frameshift_variant        Frame_Shift_Ins  ...
# 2       non_coding_transcript_exon_variant                    RNA  ...
# 3                         missense_variant      Missense_Mutation  ...
# 4                      3_prime_UTR_variant                  3'UTR  ...
# ...                                    ...                    ...  ...
# 130490                    missense_variant      Missense_Mutation  ...
# 130491                 5_prime_UTR_variant                  5'UTR  ...
# 130492                 3_prime_UTR_variant                  3'UTR  ...
# 130493             splice_acceptor_variant            Splice_Site  ...
# 130494             splice_acceptor_variant            Splice_Site  ...
#
#                    ENSP ExAC_AF                                   CENTERS  \
# 0       ENSP00000263461       .  SOMATICSNIPER|RADIA|MUTECT|MUSE|VARSCANS
# 1       ENSP00000368632       .             INDELOCATOR*|VARSCANI*|PINDEL
# 2                     .       .                          VARSCANI*|PINDEL
# 3       ENSP00000308117       .                           MUTECT|VARSCANS
# 4       ENSP00000311196       .                RADIA|MUTECT|MUSE|VARSCANS
# ...                 ...     ...                                       ...
# 130490  ENSP00000218089       .  MUTECT|RADIA|SOMATICSNIPER|MUSE|VARSCANS
# 130491  ENSP00000368226       .  MUTECT|RADIA|SOMATICSNIPER|MUSE|VARSCANS
# 130492  ENSP00000342680       .  MUTECT|RADIA|SOMATICSNIPER|MUSE|VARSCANS
# 130493  ENSP00000350676       .                               MUTECT|MUSE
# 130494  ENSP00000382419       .                      MUTECT|MUSE|VARSCANS
#
#                CCDS   EXON ExAC_AF_OTH SAS_MAF Exon_Number MINIMISED PUBMED
# 0        CCDS7619.1  29/29           .       .       29/29         .      .
# 1       CCDS31143.1    6/6           .       .         6/6         .      .
# 2                 .    1/1           .       .         1/1         .      .
# 3        CCDS8134.1    1/1           .     T:0         1/1         .      .
# 4        CCDS8138.1    8/8           .       .         8/8         .      .
# ...             ...    ...         ...     ...         ...       ...    ...
# 130490  CCDS43990.1  29/35           .       .       29/35         .      .
# 130491  CCDS48090.1   1/20           .       .        1/20         .      .
# 130492            .    1/1           .       .         1/1         .      .
# 130493  CCDS55420.1      .           .       .           .         .      .
# 130494  CCDS42420.1      .           .       .           .         .      .
#
# [130495 rows x 113 columns]

# %%
mutations_mskcc.columns[:50]
# Out:
# Index(['Hugo_Symbol', 'Entrez_Gene_Id', 'Center', 'NCBI_Build', 'Chromosome',
#        'Start_Position', 'End_Position', 'Strand', 'Consequence',
#        'Variant_Classification', 'Variant_Type', 'Reference_Allele',
#        'Tumor_Seq_Allele1', 'Tumor_Seq_Allele2', 'dbSNP_RS',
#        'dbSNP_Val_Status', 'Tumor_Sample_Barcode',
#        'Matched_Norm_Sample_Barcode', 'Match_Norm_Seq_Allele1',
#        'Match_Norm_Seq_Allele2', 'Tumor_Validation_Allele1',
#        'Tumor_Validation_Allele2', 'Match_Norm_Validation_Allele1',
#        'Match_Norm_Validation_Allele2', 'Verification_Status',
#        'Validation_Status', 'Mutation_Status', 'Sequencing_Phase',
#        'Sequence_Source', 'Validation_Method', 'Score', 'BAM_File',
#        'Sequencer', 't_ref_count', 't_alt_count', 'n_ref_count', 'n_alt_count',
#        'HGVSc', 'HGVSp', 'HGVSp_Short', 'Transcript_ID', 'RefSeq',
#        'Protein_position', 'Codons', 'Hotspot', 'NCALLERS', 'ALLELE_NUM',
#        'PICK', 'UNIPARC', 'n_depth'],
#       dtype='object')

# %%
mutations_mskcc.columns[0:113]
# Out:
# Index(['Hugo_Symbol', 'Entrez_Gene_Id', 'Center', 'NCBI_Build', 'Chromosome',
#        'Start_Position', 'End_Position', 'Strand', 'Consequence',
#        'Variant_Classification',
#        ...
#        'ENSP', 'ExAC_AF', 'CENTERS', 'CCDS', 'EXON', 'ExAC_AF_OTH', 'SAS_MAF',
#        'Exon_Number', 'MINIMISED', 'PUBMED'],
#       dtype='object', length=113)

# %%
mutations_mskcc['Transcript_ID']
# Out:
# 0         ENST00000263461
# 1         ENST00000346208
# 2         ENST00000534336
# 3         ENST00000311330
# 4         ENST00000311034
#                ...
# 130490    ENST00000218089
# 130491    ENST00000378943
# 130492    ENST00000342995
# 130493    ENST00000357988
# 130494    ENST00000399496
# Name: Transcript_ID, Length: 130495, dtype: object
